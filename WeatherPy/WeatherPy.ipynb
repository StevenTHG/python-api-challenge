# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %%
url_ex = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key
city_url_ex = url_ex + '&q=' + cities[0]
city_weather_ex = requests.get(city_url_ex).json()
pprint(city_weather_ex)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 27.9769, 'lon': -114.0611},
#  'dt': 1680406936,
#  'id': 4021858,
#  'main': {'feels_like': 13.77,
#           'grnd_level': 1019,
#           'humidity': 79,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 14.23,
#           'temp_max': 14.23,
#           'temp_min': 14.23},
#  'name': 'Guerrero Negro',
#  'sys': {'country': 'MX', 'sunrise': 1680355591, 'sunset': 1680400406},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 323, 'gust': 10.43, 'speed': 7.71}}

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&appid=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + '&q=' + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 1 | ilulissat
# Processing Record 4 of Set 1 | milkovo
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | albany
# Processing Record 9 of Set 1 | iquique
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | mbouda
# Processing Record 12 of Set 1 | tautira
# Processing Record 13 of Set 1 | bereznik
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | vila velha
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | mount gambier
# Processing Record 19 of Set 1 | cap malheureux
# Processing Record 20 of Set 1 | saldanha
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | ponorogo
# Processing Record 24 of Set 1 | north bend
# Processing Record 25 of Set 1 | tupiza
# Processing Record 26 of Set 1 | salalah
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | sotnikovo
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | new norfolk
# Processing Record 31 of Set 1 | novoagansk
# Processing Record 32 of Set 1 | pinar del rio
# Processing Record 33 of Set 1 | mchinji
# Processing Record 34 of Set 1 | dranceni sat
# City not found. Skipping...
# Processing Record 35 of Set 1 | alice springs
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | cidreira
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | souillac
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | mahibadhoo
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | maceio
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | acarau
# Processing Record 47 of Set 1 | atar
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 0 of Set 2 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | esperance
# Processing Record 3 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 2 | pitimbu
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | tuktoyaktuk
# Processing Record 9 of Set 2 | east london
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 2 | saint-philippe
# Processing Record 13 of Set 2 | san fernando
# Processing Record 14 of Set 2 | butaritari
# Processing Record 15 of Set 2 | okha
# Processing Record 16 of Set 2 | thenzawl
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | hasaki
# Processing Record 19 of Set 2 | bluff
# Processing Record 20 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | coquimbo
# Processing Record 24 of Set 2 | tasiilaq
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | godfrey
# Processing Record 29 of Set 2 | tessalit
# Processing Record 30 of Set 2 | auki
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | tabou
# Processing Record 33 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 2 | sao filipe
# Processing Record 35 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | abu samrah
# Processing Record 38 of Set 2 | khasan
# Processing Record 39 of Set 2 | mendi
# Processing Record 40 of Set 2 | borova
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | tarakan
# Processing Record 43 of Set 2 | asaba
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | taltal
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | atuona
# Processing Record 49 of Set 2 | ribeira grande
# Processing Record 0 of Set 3 | ushuaia
# Processing Record 1 of Set 3 | bambous virieux
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | kavieng
# Processing Record 4 of Set 3 | margate
# Processing Record 5 of Set 3 | lebu
# Processing Record 6 of Set 3 | arlit
# Processing Record 7 of Set 3 | dryden
# Processing Record 8 of Set 3 | mehamn
# Processing Record 9 of Set 3 | bathsheba
# Processing Record 10 of Set 3 | katsuura
# Processing Record 11 of Set 3 | provideniya
# Processing Record 12 of Set 3 | neiafu
# Processing Record 13 of Set 3 | shebalino
# Processing Record 14 of Set 3 | muroto
# Processing Record 15 of Set 3 | khilok
# Processing Record 16 of Set 3 | kyshtovka
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | aklavik
# Processing Record 19 of Set 3 | vila franca do campo
# Processing Record 20 of Set 3 | rawson
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | yermakovskoye
# Processing Record 23 of Set 3 | kodiak
# Processing Record 24 of Set 3 | puerto escondido
# Processing Record 25 of Set 3 | mayo
# Processing Record 26 of Set 3 | bonavista
# Processing Record 27 of Set 3 | port alfred
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 3 | quatre cocos
# Processing Record 32 of Set 3 | saint-georges
# Processing Record 33 of Set 3 | roald
# Processing Record 34 of Set 3 | oussouye
# Processing Record 35 of Set 3 | lao cai
# Processing Record 36 of Set 3 | bandarbeyla
# Processing Record 37 of Set 3 | arica
# Processing Record 38 of Set 3 | berdigestyakh
# Processing Record 39 of Set 3 | kahului
# Processing Record 40 of Set 3 | bengkulu
# Processing Record 41 of Set 3 | madisonville
# Processing Record 42 of Set 3 | zatoka
# Processing Record 43 of Set 3 | stara vyzhivka
# Processing Record 44 of Set 3 | isfana
# Processing Record 45 of Set 3 | montepuez
# Processing Record 46 of Set 3 | wadi musa
# Processing Record 47 of Set 3 | galdar
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | lata
# Processing Record 0 of Set 4 | ziro
# Processing Record 1 of Set 4 | sobolevo
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | sinkat
# City not found. Skipping...
# Processing Record 4 of Set 4 | bilma
# Processing Record 5 of Set 4 | yerbogachen
# Processing Record 6 of Set 4 | kieta
# Processing Record 7 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 4 | geraldton
# Processing Record 9 of Set 4 | shaki
# Processing Record 10 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 4 | caravelas
# Processing Record 12 of Set 4 | hamilton
# Processing Record 13 of Set 4 | bay roberts
# Processing Record 14 of Set 4 | leningradskiy
# Processing Record 15 of Set 4 | gikongoro
# Processing Record 16 of Set 4 | oktyabrskoye
# Processing Record 17 of Set 4 | bintulu
# Processing Record 18 of Set 4 | kapiri mposhi
# Processing Record 19 of Set 4 | severo-kurilsk
# Processing Record 20 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 4 | veinticinco de mayo
# Processing Record 22 of Set 4 | ossora
# Processing Record 23 of Set 4 | pemangkat
# Processing Record 24 of Set 4 | rettikhovka
# Processing Record 25 of Set 4 | raudeberg
# Processing Record 26 of Set 4 | chokurdakh
# Processing Record 27 of Set 4 | ailigandi
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | buala
# Processing Record 30 of Set 4 | upernavik
# Processing Record 31 of Set 4 | victoria
# Processing Record 32 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 4 | port lincoln
# Processing Record 34 of Set 4 | port-gentil
# Processing Record 35 of Set 4 | coihaique
# Processing Record 36 of Set 4 | jatiroto
# Processing Record 37 of Set 4 | ponta delgada
# Processing Record 38 of Set 4 | plettenberg bay
# Processing Record 39 of Set 4 | laguna
# Processing Record 40 of Set 4 | kuytun
# Processing Record 41 of Set 4 | port-cartier
# Processing Record 42 of Set 4 | komsomolskiy
# Processing Record 43 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 44 of Set 4 | alofi
# Processing Record 45 of Set 4 | sioux lookout
# Processing Record 46 of Set 4 | airai
# Processing Record 47 of Set 4 | pombas
# Processing Record 48 of Set 4 | port hardy
# Processing Record 49 of Set 4 | puerto cabezas
# Processing Record 0 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 5 | falmouth
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | waingapu
# Processing Record 4 of Set 5 | helong
# Processing Record 5 of Set 5 | nizhneshilovka
# City not found. Skipping...
# Processing Record 6 of Set 5 | mayumba
# Processing Record 7 of Set 5 | avera
# Processing Record 8 of Set 5 | shirokiy
# Processing Record 9 of Set 5 | kamen-rybolov
# Processing Record 10 of Set 5 | mbini
# Processing Record 11 of Set 5 | colares
# Processing Record 12 of Set 5 | zaplyusye
# City not found. Skipping...
# Processing Record 13 of Set 5 | metro
# Processing Record 14 of Set 5 | henties bay
# Processing Record 15 of Set 5 | port blair
# Processing Record 16 of Set 5 | aneho
# Processing Record 17 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 5 | zunyi
# Processing Record 19 of Set 5 | nelson bay
# Processing Record 20 of Set 5 | cairns
# Processing Record 21 of Set 5 | kruisfontein
# Processing Record 22 of Set 5 | slave lake
# Processing Record 23 of Set 5 | ambunti
# Processing Record 24 of Set 5 | popondetta
# Processing Record 25 of Set 5 | bermejillo
# Processing Record 26 of Set 5 | dzilam gonzalez
# Processing Record 27 of Set 5 | hambantota
# Processing Record 28 of Set 5 | kanniyakumari
# Processing Record 29 of Set 5 | pavlohrad
# Processing Record 30 of Set 5 | mount isa
# Processing Record 31 of Set 5 | saint-joseph
# Processing Record 32 of Set 5 | puerto del rosario
# Processing Record 33 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 5 | ponta do sol
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | dikson
# Processing Record 37 of Set 5 | buluang
# Processing Record 38 of Set 5 | yakeshi
# Processing Record 39 of Set 5 | barra patuca
# Processing Record 40 of Set 5 | port moresby
# Processing Record 41 of Set 5 | hailar
# Processing Record 42 of Set 5 | wanaka
# Processing Record 43 of Set 5 | doha
# Processing Record 44 of Set 5 | balkhash
# Processing Record 45 of Set 5 | luderitz
# Processing Record 46 of Set 5 | grindavik
# Processing Record 47 of Set 5 | kinablangan
# Processing Record 48 of Set 5 | lodwar
# Processing Record 49 of Set 5 | viedma
# Processing Record 0 of Set 6 | puerto maldonado
# Processing Record 1 of Set 6 | koran
# Processing Record 2 of Set 6 | smithers
# Processing Record 3 of Set 6 | coruripe
# Processing Record 4 of Set 6 | inyonga
# Processing Record 5 of Set 6 | lawan kuda baharu
# City not found. Skipping...
# Processing Record 6 of Set 6 | saint george
# Processing Record 7 of Set 6 | yumen
# Processing Record 8 of Set 6 | san francisco
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | yenagoa
# Processing Record 11 of Set 6 | wanning
# Processing Record 12 of Set 6 | pangkalanbuun
# Processing Record 13 of Set 6 | blagoyevo
# Processing Record 14 of Set 6 | pevek
# Processing Record 15 of Set 6 | oranjemund
# Processing Record 16 of Set 6 | ndele
# Processing Record 17 of Set 6 | umm durman
# City not found. Skipping...
# Processing Record 18 of Set 6 | mabaruma
# Processing Record 19 of Set 6 | labuan
# Processing Record 20 of Set 6 | srednekolymsk
# Processing Record 21 of Set 6 | iqaluit
# Processing Record 22 of Set 6 | general roca
# Processing Record 23 of Set 6 | medianeira
# Processing Record 24 of Set 6 | samarai
# Processing Record 25 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 27 of Set 6 | hobyo
# Processing Record 28 of Set 6 | atakpame
# Processing Record 29 of Set 6 | touros
# Processing Record 30 of Set 6 | fairbanks
# Processing Record 31 of Set 6 | lundamo
# Processing Record 32 of Set 6 | khatanga
# Processing Record 33 of Set 6 | shangrao
# Processing Record 34 of Set 6 | williston
# Processing Record 35 of Set 6 | egvekinot
# Processing Record 36 of Set 6 | iskele
# Processing Record 37 of Set 6 | ornskoldsvik
# Processing Record 38 of Set 6 | quartucciu
# Processing Record 39 of Set 6 | tainan
# Processing Record 40 of Set 6 | shestakovo
# Processing Record 41 of Set 6 | astana
# Processing Record 42 of Set 6 | sao miguel do araguaia
# Processing Record 43 of Set 6 | broome
# Processing Record 44 of Set 6 | boa esperanca
# Processing Record 45 of Set 6 | roquetas de mar
# Processing Record 46 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | joao pinheiro
# Processing Record 49 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 0 of Set 7 | batagay-alyta
# Processing Record 1 of Set 7 | tuatapere
# Processing Record 2 of Set 7 | tual
# Processing Record 3 of Set 7 | codrington
# Processing Record 4 of Set 7 | rey bouba
# Processing Record 5 of Set 7 | vizinga
# Processing Record 6 of Set 7 | vostok
# Processing Record 7 of Set 7 | marsabit
# Processing Record 8 of Set 7 | faya
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | kamenka
# Processing Record 11 of Set 7 | papasquiaro
# City not found. Skipping...
# Processing Record 12 of Set 7 | mukhen
# Processing Record 13 of Set 7 | bubaque
# Processing Record 14 of Set 7 | alamosa
# Processing Record 15 of Set 7 | rio grande
# Processing Record 16 of Set 7 | san patricio
# Processing Record 17 of Set 7 | cherskiy
# Processing Record 18 of Set 7 | saint-augustin
# Processing Record 19 of Set 7 | vila
# Processing Record 20 of Set 7 | adrar
# Processing Record 21 of Set 7 | hualmay
# Processing Record 22 of Set 7 | pielesti
# Processing Record 23 of Set 7 | boguchany
# Processing Record 24 of Set 7 | arman
# Processing Record 25 of Set 7 | asfi
# Processing Record 26 of Set 7 | ampanihy
# Processing Record 27 of Set 7 | kjollefjord
# Processing Record 28 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 7 | kurchum
# Processing Record 30 of Set 7 | ust-tsilma
# Processing Record 31 of Set 7 | bandundu
# Processing Record 32 of Set 7 | shyroke
# Processing Record 33 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | pangnirtung
# Processing Record 36 of Set 7 | tshikapa
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | hovd
# Processing Record 39 of Set 7 | thompson
# Processing Record 40 of Set 7 | nhulunbuy
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | great yarmouth
# Processing Record 43 of Set 7 | taoudenni
# Processing Record 44 of Set 7 | okhotsk
# Processing Record 45 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 7 | ust-kuyga
# Processing Record 47 of Set 7 | kirakira
# Processing Record 48 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | manzanillo
# Processing Record 0 of Set 8 | krasnyy chikoy
# Processing Record 1 of Set 8 | kaitangata
# Processing Record 2 of Set 8 | ous
# Processing Record 3 of Set 8 | svetlaya
# Processing Record 4 of Set 8 | uyuni
# Processing Record 5 of Set 8 | barpathar
# Processing Record 6 of Set 8 | san quintin
# Processing Record 7 of Set 8 | dingle
# Processing Record 8 of Set 8 | cururupu
# Processing Record 9 of Set 8 | kapoeta
# Processing Record 10 of Set 8 | draguseni
# Processing Record 11 of Set 8 | kununurra
# Processing Record 12 of Set 8 | todos santos
# Processing Record 13 of Set 8 | amasia
# Processing Record 14 of Set 8 | kardla
# Processing Record 15 of Set 8 | itaituba
# Processing Record 16 of Set 8 | yatou
# Processing Record 17 of Set 8 | asau
# Processing Record 18 of Set 8 | harihar
# Processing Record 19 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 8 | mogadishu
# Processing Record 21 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 22 of Set 8 | pemba
# Processing Record 23 of Set 8 | korla
# Processing Record 24 of Set 8 | solnechnyy
# Processing Record 25 of Set 8 | naraina
# Processing Record 26 of Set 8 | westfield
# Processing Record 27 of Set 8 | vagur
# Processing Record 28 of Set 8 | ahipara
# Processing Record 29 of Set 8 | nadvoitsy
# Processing Record 30 of Set 8 | kalmunai
# Processing Record 31 of Set 8 | lazaro cardenas
# Processing Record 32 of Set 8 | weiser
# Processing Record 33 of Set 8 | zeya
# Processing Record 34 of Set 8 | constitucion
# Processing Record 35 of Set 8 | pauini
# Processing Record 36 of Set 8 | ishigaki
# Processing Record 37 of Set 8 | winnemucca
# Processing Record 38 of Set 8 | santa maria
# Processing Record 39 of Set 8 | la ronge
# Processing Record 40 of Set 8 | chicama
# Processing Record 41 of Set 8 | kabwe
# Processing Record 42 of Set 8 | inhambane
# Processing Record 43 of Set 8 | rolla
# Processing Record 44 of Set 8 | muravlenko
# Processing Record 45 of Set 8 | badou
# Processing Record 46 of Set 8 | shache
# Processing Record 47 of Set 8 | holme
# Processing Record 48 of Set 8 | dwarka
# Processing Record 49 of Set 8 | fare
# Processing Record 0 of Set 9 | arvika
# Processing Record 1 of Set 9 | bongandanga
# Processing Record 2 of Set 9 | aktanysh
# Processing Record 3 of Set 9 | mackay
# Processing Record 4 of Set 9 | opuwo
# Processing Record 5 of Set 9 | terrace bay
# Processing Record 6 of Set 9 | san cristobal
# Processing Record 7 of Set 9 | tsimlyansk
# Processing Record 8 of Set 9 | ancud
# Processing Record 9 of Set 9 | nemuro
# Processing Record 10 of Set 9 | krasnogvardeyskiy
# Processing Record 11 of Set 9 | svetlyy
# Processing Record 12 of Set 9 | pangdan
# Processing Record 13 of Set 9 | husavik
# Processing Record 14 of Set 9 | hounde
# Processing Record 15 of Set 9 | payson
# Processing Record 16 of Set 9 | nalut
# Processing Record 17 of Set 9 | loa janan
# Processing Record 18 of Set 9 | longyearbyen
# Processing Record 19 of Set 9 | umm lajj
# Processing Record 20 of Set 9 | helena
# Processing Record 21 of Set 9 | gumdag
# Processing Record 22 of Set 9 | bilimbay
# Processing Record 23 of Set 9 | aranos
# Processing Record 24 of Set 9 | bukachacha
# Processing Record 25 of Set 9 | gazanjyk
# Processing Record 26 of Set 9 | xining
# Processing Record 27 of Set 9 | carnarvon
# Processing Record 28 of Set 9 | rocha
# Processing Record 29 of Set 9 | bac lieu
# Processing Record 30 of Set 9 | mazamari
# Processing Record 31 of Set 9 | dunedin
# Processing Record 32 of Set 9 | hastings
# Processing Record 33 of Set 9 | deputatskiy
# Processing Record 34 of Set 9 | mogok
# Processing Record 35 of Set 9 | nanortalik
# Processing Record 36 of Set 9 | tangkak
# Processing Record 37 of Set 9 | norman wells
# Processing Record 38 of Set 9 | fort nelson
# Processing Record 39 of Set 9 | bereda
# Processing Record 40 of Set 9 | champerico
# Processing Record 41 of Set 9 | aksu
# Processing Record 42 of Set 9 | palmas
# Processing Record 43 of Set 9 | flinders
# Processing Record 44 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 9 | progreso
# Processing Record 46 of Set 9 | kharitonovo
# Processing Record 47 of Set 9 | sandwick
# Processing Record 48 of Set 9 | urengoy
# Processing Record 49 of Set 9 | wawa
# Processing Record 0 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 10 | skagen
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | beira
# Processing Record 4 of Set 10 | dole
# Processing Record 5 of Set 10 | bom jesus
# Processing Record 6 of Set 10 | angol
# Processing Record 7 of Set 10 | piet retief
# Processing Record 8 of Set 10 | marystown
# Processing Record 9 of Set 10 | hofn
# Processing Record 10 of Set 10 | tariba
# Processing Record 11 of Set 10 | sherbakul
# Processing Record 12 of Set 10 | halifax
# Processing Record 13 of Set 10 | ahuimanu
# Processing Record 14 of Set 10 | blind river
# Processing Record 15 of Set 10 | skjervoy
# Processing Record 16 of Set 10 | tibu
# Processing Record 17 of Set 10 | kalianget
# Processing Record 18 of Set 10 | altamira
# Processing Record 19 of Set 10 | beringovskiy
# Processing Record 20 of Set 10 | lima
# Processing Record 21 of Set 10 | banjar
# Processing Record 22 of Set 10 | baijiantan
# Processing Record 23 of Set 10 | evensk
# Processing Record 24 of Set 10 | huntington
# Processing Record 25 of Set 10 | marsaxlokk
# Processing Record 26 of Set 10 | tillabery
# City not found. Skipping...
# Processing Record 27 of Set 10 | zaidpur
# Processing Record 28 of Set 10 | khudumelapye
# Processing Record 29 of Set 10 | ambilobe
# Processing Record 30 of Set 10 | usinsk
# Processing Record 31 of Set 10 | bonthe
# Processing Record 32 of Set 10 | ler
# Processing Record 33 of Set 10 | olinda
# Processing Record 34 of Set 10 | anchorage
# Processing Record 35 of Set 10 | gibara
# Processing Record 36 of Set 10 | kitgum
# Processing Record 37 of Set 10 | leeton
# Processing Record 38 of Set 10 | haines junction
# Processing Record 39 of Set 10 | villazon
# Processing Record 40 of Set 10 | dawlatabad
# Processing Record 41 of Set 10 | matara
# Processing Record 42 of Set 10 | kiama
# Processing Record 43 of Set 10 | westport
# Processing Record 44 of Set 10 | marsa matruh
# Processing Record 45 of Set 10 | urubicha
# Processing Record 46 of Set 10 | saint-pierre
# Processing Record 47 of Set 10 | kijang
# Processing Record 48 of Set 10 | severo-yeniseyskiy
# Processing Record 49 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 0 of Set 11 | banda aceh
# Processing Record 1 of Set 11 | tiznit
# Processing Record 2 of Set 11 | coatepec harinas
# Processing Record 3 of Set 11 | along
# Processing Record 4 of Set 11 | luxor
# Processing Record 5 of Set 11 | kushima
# Processing Record 6 of Set 11 | yanam
# Processing Record 7 of Set 11 | pasighat
# Processing Record 8 of Set 11 | aberlour
# City not found. Skipping...
# Processing Record 9 of Set 11 | ankang
# Processing Record 10 of Set 11 | yarovoye
# Processing Record 11 of Set 11 | coahuayana
# Processing Record 12 of Set 11 | cabra
# Processing Record 13 of Set 11 | eregli
# Processing Record 14 of Set 11 | chapais
# Processing Record 15 of Set 11 | yushu
# Processing Record 16 of Set 11 | nago
# Processing Record 17 of Set 11 | bekhtery
# Processing Record 18 of Set 11 | tarko-sale
# Processing Record 19 of Set 11 | babu
# Processing Record 20 of Set 11 | belmopan
# Processing Record 21 of Set 11 | coolum beach
# Processing Record 22 of Set 11 | maine-soroa
# Processing Record 23 of Set 11 | lakki marwat
# Processing Record 24 of Set 11 | weligama
# Processing Record 25 of Set 11 | akom
# Processing Record 26 of Set 11 | zurrieq
# Processing Record 27 of Set 11 | puerto ayacucho
# Processing Record 28 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 11 | ayan
# Processing Record 30 of Set 11 | mirebalais
# Processing Record 31 of Set 11 | padang
# Processing Record 32 of Set 11 | knysna
# Processing Record 33 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 11 | nagorsk
# Processing Record 35 of Set 11 | talcahuano
# Processing Record 36 of Set 11 | voh
# Processing Record 37 of Set 11 | kapit
# Processing Record 38 of Set 11 | mwense
# Processing Record 39 of Set 11 | casambalangan
# Processing Record 40 of Set 11 | teguldet
# Processing Record 41 of Set 11 | tombouctou
# Processing Record 42 of Set 11 | houma
# Processing Record 43 of Set 11 | yeppoon
# Processing Record 44 of Set 11 | baghdad
# Processing Record 45 of Set 11 | chumikan
# Processing Record 46 of Set 11 | luanda
# Processing Record 47 of Set 11 | north platte
# Processing Record 48 of Set 11 | the valley
# Processing Record 49 of Set 11 | letterkenny
# Processing Record 0 of Set 12 | thai binh
# Processing Record 1 of Set 12 | agirish
# Processing Record 2 of Set 12 | praia da vitoria
# Processing Record 3 of Set 12 | necochea
# Processing Record 4 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 5 of Set 12 | carmo do paranaiba
# Processing Record 6 of Set 12 | buchanan
# Processing Record 7 of Set 12 | glasgow
# Processing Record 8 of Set 12 | gobabis
# Processing Record 9 of Set 12 | hvammstangi
# City not found. Skipping...
# Processing Record 10 of Set 12 | sulangan
# Processing Record 11 of Set 12 | tevaitoa
# Processing Record 12 of Set 12 | amapa
# Processing Record 13 of Set 12 | cockburn town
# Processing Record 14 of Set 12 | daru
# Processing Record 15 of Set 12 | kimbe
# Processing Record 16 of Set 12 | sao paulo de olivenca
# Processing Record 17 of Set 12 | oliveira dos brejinhos
# Processing Record 18 of Set 12 | dois vizinhos
# Processing Record 19 of Set 12 | yevsino
# Processing Record 20 of Set 12 | nicolas bravo
# Processing Record 21 of Set 12 | riyadh
# Processing Record 22 of Set 12 | acajutla
# Processing Record 23 of Set 12 | manicore
# Processing Record 24 of Set 12 | trofors
# Processing Record 25 of Set 12 | unye
# City not found. Skipping...
# Processing Record 26 of Set 12 | berbera
# Processing Record 27 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 12 | jequitinhonha
# Processing Record 29 of Set 12 | aksarka
# Processing Record 30 of Set 12 | bangassou
# Processing Record 31 of Set 12 | puerto lopez
# Processing Record 32 of Set 12 | darhan
# Processing Record 33 of Set 12 | nosy varika
# Processing Record 34 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 35 of Set 12 | tongling
# Processing Record 36 of Set 12 | urumqi
# Processing Record 37 of Set 12 | nome
# Processing Record 38 of Set 12 | talnakh
# Processing Record 39 of Set 12 | marawi
# Processing Record 40 of Set 12 | high rock
# Processing Record 41 of Set 12 | comodoro rivadavia
# Processing Record 42 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 12 | arcelia
# Processing Record 44 of Set 12 | riachao das neves
# Processing Record 45 of Set 12 | isangel
# Processing Record 46 of Set 12 | alta floresta
# Processing Record 47 of Set 12 | minas
# Processing Record 48 of Set 12 | namibe
# Processing Record 49 of Set 12 | shingu
# Processing Record 0 of Set 13 | pastrana
# Processing Record 1 of Set 13 | caconda
# Processing Record 2 of Set 13 | khromtau
# Processing Record 3 of Set 13 | lucapa
# Processing Record 4 of Set 13 | broken hill
# Processing Record 5 of Set 13 | dubti
# Processing Record 6 of Set 13 | mazyr
# Processing Record 7 of Set 13 | ferme-neuve
# Processing Record 8 of Set 13 | half moon bay
# Processing Record 9 of Set 13 | killybegs
# Processing Record 10 of Set 13 | una
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  guerrero negro  27.9769 -114.0611     14.23        79           3
# 1       ilulissat  69.2167  -51.1000    -19.99        84          63
# 2         milkovo  54.7167  158.6167      5.01        61           2
# 3         rikitea -23.1203 -134.9692     26.58        82          81
# 4       busselton -33.6500  115.3333     24.63        49           0
#
#    Wind Speed Country        Date
# 0        7.71      MX  1680406936
# 1        3.09      GL  1680406940
# 2        0.47      RU  1680406940
# 3        6.49      PF  1680406941
# 4        1.63      AU  1680406941

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        guerrero negro  27.9769 -114.0611     14.23        79           3
# 1             ilulissat  69.2167  -51.1000    -19.99        84          63
# 2               milkovo  54.7167  158.6167      5.01        61           2
# 3               rikitea -23.1203 -134.9692     26.58        82          81
# 4             busselton -33.6500  115.3333     24.63        49           0
#
#          Wind Speed Country        Date
# City_ID
# 0              7.71      MX  1680406936
# 1              3.09      GL  1680406940
# 2              0.47      RU  1680406940
# 3              6.49      PF  1680406941
# 4              1.63      AU  1680406941

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'],marker='o',edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title(f"City Latitude vs. Max Temperature ({time.strftime('%Y-%m-%d')})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'],marker='o',edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f"City Latitude vs. Humidity ({time.strftime('%Y-%m-%d')})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'],marker='o',edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f"City Latitude vs. Cloudiness ({time.strftime('%Y-%m-%d')})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'],marker='o',edgecolors='black')

# Incorporate the other graph properties
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title(f"City Latitude vs. Wind Speed ({time.strftime('%Y-%m-%d')})")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        guerrero negro  27.9769 -114.0611     14.23        79           3
# 1             ilulissat  69.2167  -51.1000    -19.99        84          63
# 2               milkovo  54.7167  158.6167      5.01        61           2
# 5                 tiksi  71.6872  128.8694    -14.44        79         100
# 6                albany  42.6001  -73.9662      8.84        81         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.71      MX  1680406936
# 1              3.09      GL  1680406940
# 2              0.47      RU  1680406940
# 5             13.13      RU  1680406942
# 6              2.24      US  1680406607

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3          rikitea -23.1203 -134.9692     26.58        82          81
# 4        busselton -33.6500  115.3333     24.63        49           0
# 7          iquique -20.2208  -70.1431     22.02        83          96
# 8           avarua -21.2078 -159.7750     27.03        78          75
# 10         tautira -17.7333 -149.1500     28.23        73           4
#
#          Wind Speed Country        Date
# City_ID
# 3              6.49      PF  1680406941
# 4              1.63      AU  1680406941
# 7              0.10      CL  1680406942
# 8              2.57      CK  1680406943
# 10             3.66      PF  1680406944

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(10,-10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.8983971461736685

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.6584380987384628

# %% [markdown]
# **Discussion about the linear relationship:** Here, we see that the data in northern hemisphere plot results in an r-value of -0.899, which indicates a strong negative correlation between latitude and max temp. As observed, the higher the latitude, the lower the max temp. However, the data in the southern hemisphere plot results in an r-value of 0.658, which indicates a strong positive correlation between latitude and max temp. As we can see in this chart, the higher the latitude, the higher the max temp.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.1955896247417461

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.28593197947263727

# %% [markdown]
# **Discussion about the linear relationship:** Unlike the max temperature plots, these plots on humidity displayed r-values very close to 0. This means that latitude and humidity weak or no correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(30,45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.2124880271582889

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,45),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.29852408427159044

# %% [markdown]
# **Discussion about the linear relationship:** Similarly to the plots on humidity, these plots also showed r-values close to 0, which also means that latitude and cloudiness have weak or no correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,15),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.21792629028113994

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,7),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.28343426801380966

# %% [markdown]
# **Discussion about the linear relationship:** Finally, these plots also showed r-values close to 0, which also means that latitude and wind speed have weak or no correlation.
